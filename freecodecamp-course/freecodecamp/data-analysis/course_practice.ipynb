# %% [markdown]
# ## BASIC NUMPY COMMANDS

# %%
import numpy as np

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
a = np.array([10,9,8,7])
b = np.array([0.2,0.4,0.6])

# %%
a[0] , a[2]
# Out:
# (np.int64(10), np.int64(8))

# %%
a[1:3]
# Out:
# array([9, 8])
